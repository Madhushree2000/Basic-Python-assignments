# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D

# %%
df = pd.read_csv('IRIS.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
del df['species']

# %%
df['mean'] = df.mean(axis=1)

# %%
df['min'] = df.min(axis=1)

# %%
df['max'] = df.max(axis=1)

# %%
df['std'] = df.std(axis=1)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width   mean  min  max  \
# 0           5.1          3.5           1.4          0.2  2.550  0.2  5.1
# 1           4.9          3.0           1.4          0.2  2.375  0.2  4.9
# 2           4.7          3.2           1.3          0.2  2.350  0.2  4.7
# 3           4.6          3.1           1.5          0.2  2.350  0.2  4.6
# 4           5.0          3.6           1.4          0.2  2.550  0.2  5.0
#
#         std
# 0  2.092418
# 1  1.980583
# 2  1.919604
# 3  1.855333
# 4  2.060484

# %%
x = df['mean']
y = df['min']
z = df['max']
w = df['std']

# %%
plt.subplot(2,3,1)
plt.scatter(x,y, c = 'r')
plt.subplot(2,3,2)
plt.plot(y,z)
plt.show()

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(x, y, z,)
ax.set_xlabel('mean')
ax.set_ylabel('min')
ax.set_zlabel('max')
plt.show()
